# %% [markdown]
# ### STOCK MARKET API

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "https://cloud.iexapis.com/stable/stock/aapl/chart/3m?token=pk_7a28f856bfda4207a2df5b00551e5176"
api_data = requests.get(url).json()

# %%
apple_stock_df = pd.DataFrame.from_dict(api_data)

# %% [markdown]
# ## converting date to datetime object

# %%
apple_stock_df['date'] = pd.to_datetime(apple_stock_df['date'], format="%Y-%m-%d")

# %% [markdown]
# ## set the date column as index

# %%
apple_stock_df = apple_stock_df.set_index('date')

# %% [markdown]
# ## first plot only the values in the 'close' column

# %%
apple_stock_df['close'].plot()

# %% [markdown]
# ## plot with the value in 'open', 'close', 'high', 'low'

# %%
apple_stock_df[['open', 'close', 'high', 'low']].plot()

# %%
apple_stock_df[['open', 'close', 'high', 'low']].plot(figsize=(12,4))

# %% [markdown]
# Amazon stock prices since last year?
# https://cloud.iexapis.com/stable/stock/amzn/chart/1y?token=YOUR_API_KEY

# %% [markdown]
# Facebook market cap?
# https://cloud.iexapis.com/stable/stock/fb/stats?token=YOUR_API_KEY

# %% [markdown]
# Apple research and development spendings quarterly?
# https://cloud.iexapis.com/stable/stock/aapl/financials?token=YOUR_API_KEY

# %% [markdown]
# The last news about Tesla?
# https://cloud.iexapis.com/stable/stock/tsla/news/last/1?token=YOUR_API_KEY

# %%
The performance of the ‘Energy’ sector?
